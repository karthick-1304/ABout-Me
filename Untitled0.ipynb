# %% [markdown]
# <a href="https://colab.research.google.com/github/karthick-1304/ABout-Me/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/karthick-1304/Currency_Detection_.git
# %cd Currency_Detection_
# Out:
# Cloning into 'Currency_Detection_'...
# remote: Enumerating objects: 17624, done.
# remote: Counting objects: 100% (26/26), done.
# remote: Compressing objects: 100% (25/25), done.
# remote: Total 17624 (delta 11), reused 0 (delta 0), pack-reused 17598 (from 1)
# Receiving objects: 100% (17624/17624), 731.47 MiB | 33.08 MiB/s, done.
# Resolving deltas: 100% (23/23), done.
# Updating files: 100% (17954/17954), done.
# /content/Currency_Detection_

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -r requirements.txt
# !pip install ultralytics torch torchvision timm opencv-python pywavelets scikit-learn matplotlib tqdm
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 20.0 MB/s eta 0:00:00
# ...

# %%
# !python src/roi_infer_and_crop.py --weights runs/detect/currency_yolo87/weights/best.pt
# Out:
# Cropping train: 100% 7447/7447 [34:42<00:00,  3.58it/s]
# Cropping valid: 100% 867/867 [04:08<00:00,  3.49it/s]
# Cropping test: 100% 645/645 [03:04<00:00,  3.49it/s]

# %%
# !pwd
# Out:
# /content/Currency_Detection_

# %%
# !ls /content/Currency_Detection_/runs/detect
# Out:
# currency_yolo87  currency_yolov82  currency_yolov84  currency_yolov86
# currency_yolov8  currency_yolov83  currency_yolov85
